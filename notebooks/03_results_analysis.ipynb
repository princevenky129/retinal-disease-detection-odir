# %% [markdown]
# # Phase 7-8: Post-training results analysis, GradCAM, attention maps
# Run after a checkpoint exists at checkpoints/best_model.pth

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from src.inference.predict import load_model_for_inference, predict_single_image

model, cfg, device = load_model_for_inference('../config/config.yaml')
print('Model loaded.')
